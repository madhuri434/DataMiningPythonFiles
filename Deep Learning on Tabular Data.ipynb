# %% [markdown]
# yeah typically regularization is very, very helpful than your variables are correlated so, then what you're trying to say you know hey some quantities come up as important, but they're very close to zero so so the reservation is doing that are also handling the case when X could be.

# %% [markdown]
# So the so these would be so because it ui is continuous we want regression based approaches so linear regression polynomial regression spline regression ridge,  LASSO.
#
# decision tree regressor

# %% [markdown]
# or random forest reggressor for continuous variables

# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
# %matplotlib inline

# %%
df = pd.read_csv("train_model_fitting.csv")
df.sample(5)
# Out:
#        Year_Factor State_Factor building_class              facility_type  \
# 54490            6      State_6     Commercial  Education_Other_classroom
# 26829            3      State_6    Residential  Multifamily_Uncategorized
# 75050            6     State_11    Residential        5plus_Unit_Building
# 17268            2      State_6    Residential  Multifamily_Uncategorized
# 55765            6      State_6    Residential  Multifamily_Uncategorized
#
#        floor_area  year_built  energy_star_rating  ELEVATION  \
# 54490    104400.0      1929.0                73.0        3.4
# 26829    164336.0      1941.0                 NaN       25.6
# 75050    305925.0      2013.0               100.0       26.5
# 17268     65151.0      1908.0                 NaN       11.9
# 55765     86576.0      1903.0                82.0        3.4
#
#        january_min_temp  january_avg_temp  ...  days_above_80F  \
# 54490                11         34.451613  ...              96
# ...

# %%
pd.to_numeric(df.Year_Factor)

#pd.to_numeric(df.building_class)
#pd.to_numeric(df.facility_type)
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 75752    6
# 75753    6
# 75754    6
# 75755    6
# 75756    6
# Name: Year_Factor, Length: 75757, dtype: int64

# %%
df.dtypes
# Out:
# Year_Factor                    int64
# State_Factor                  object
# building_class                object
# facility_type                 object
# floor_area                   float64
#                               ...
# direction_peak_wind_speed    float64
# max_wind_speed               float64
# days_with_fog                float64
# site_eui                     float64
# id                             int64
# Length: 64, dtype: object

# %%
df.drop('State_Factor',axis='columns',inplace=True)

# %%
df.drop('building_class',axis='columns',inplace=True)
df.drop('facility_type',axis='columns',inplace=True)

# %%
df.dtypes
# Out:
# floor_area                   float64
# year_built                   float64
# energy_star_rating           float64
# ELEVATION                    float64
# january_min_temp               int64
# january_avg_temp             float64
# january_max_temp               int64
# february_min_temp              int64
# february_avg_temp            float64
# february_max_temp              int64
# march_min_temp                 int64
# march_avg_temp               float64
# march_max_temp                 int64
# april_min_temp                 int64
# april_avg_temp               float64
# april_max_temp                 int64
# may_min_temp                   int64
# may_avg_temp                 float64
# may_max_temp                   int64
# june_min_temp                  int64
# june_avg_temp                float64
# june_max_temp                  int64
# july_min_temp                  int64
# july_avg_temp                float64
# july_max_temp                  int64
# ...

# %%
X = df.drop('site_eui',axis='columns')
y = df['site_eui']

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=5)

# %%
X_train.shape
X_test.shape
# Out:
# (15152, 61)

# %%
X_train[:10]
# Out:
#        Year_Factor State_Factor  floor_area  year_built  energy_star_rating  \
# 24936            3      State_6    292677.0      1963.0                 NaN
# 74683            6     State_11     28546.0      1917.0                99.0
# 15983            1      State_6     66577.0      1936.0                75.0
# 10374            6      State_2    343797.0      2011.0                85.0
# 17073            2      State_6     78646.0      1911.0                 NaN
# 75057            6     State_11     82087.0      2014.0               100.0
# 31064            3      State_6     54824.0      1900.0                 NaN
# 64029            6      State_6    112500.0      1929.0                74.0
# 70755            5     State_11    206000.0      1968.0                88.0
# 15131            1      State_6    100000.0      1883.0                 NaN
#
#        ELEVATION  january_min_temp  january_avg_temp  january_max_temp  \
# ...

# %%
len(X_train.columns)
# !pip3 install tf-nightly
# Out:
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# ...
#      |████████████████████████████████| 227.9 MB 40 kB/s
# ...
#      |████████████████████████████████| 438 kB 38.0 MB/s
# ...
#      |████████████████████████████████| 16.9 MB 2.1 MB/s
# ...
#      |████████████████████████████████| 1.6 MB 36.4 MB/s
# ...
#      |████████████████████████████████| 5.8 MB 11.0 MB/s
# ...
#      |████████████████████████████████| 126 kB 37.7 MB/s
# ...
#   Using cached libclang-13.0.0-py2.py3-none-macosx_10_9_x86_64.whl (13.0 MB)
# ...
#      |████████████████████████████████| 1.6 MB 42.3 MB/s
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.19.5
#     Uninstalling numpy-1.19.5:
#       Successfully uninstalled numpy-1.19.5
#   Attempting uninstall: absl-py
# ...

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import Input

model = keras.Sequential([
    keras.layers.Dense(26, input_shape=(26,), activation='relu'),
    keras.layers.Dense(15, activation='relu'),
    keras.layers.Dense(1, activation='sigmoid')
])

# opt = keras.optimizers.Adam(learning_rate=0.01)

model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

model.fit(X_train, y_train, epochs=100)
